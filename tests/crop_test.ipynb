# %%
from aquacrop.classes import    *
from aquacrop.core import       *
path = get_filepath('champion_climate.txt')
wdf = prepare_weather(path)
from aquacrop.crops.crop_params import crop_params

def run_model(year1,year2,crop_config):
    """
    funciton to run model and return results for given set of soil moisture targets
    """
    maize = CropClass('custom',PlantingDate='05/01',**crop_config) # define crop

    loam = SoilClass('SiltClayLoam') # define soil
    init_wc = InitWCClass() # define initial soil water conditions

    irrmngt = IrrMngtClass(IrrMethod=1,SMT=[70]*4,) # define irrigation management
    # irrmngt = None

    # create and run model
    model = AquaCropModel(f'{year1}/05/01',f'{year2}/12/31',wdf,loam,maize,
                          IrrMngt=irrmngt,InitWC=init_wc,)
    model.initialize()
    model.step(till_termination=True)
    return model.Outputs

# %%
temp =crop_params['Maize']
temp['SwitchGDD']=1
out1=run_model(1985,2000,temp)
# Out:
# 1 134 28009.834999999963 1537.0499999999997
# 1 134
# 2 134 26087.304999999997 1537.0499999999997
# 2 132
# 3 134 24221.794999999947 1537.0499999999997
# 3 127
# 4 134 22218.334999999952 1537.0499999999997
# 4 143
# 5 134 20361.419999999973 1537.0499999999997
# 5 135
# 6 134 18468.684999999987 1537.0499999999997
# 6 128
# 7 134 16461.084999999995 1537.0499999999997
# 7 151
# 8 134 14744.309999999998 1537.0499999999997
# 8 158
# 9 134 13020.310000000005 1537.0499999999997
# 9 126
# 10 134 11029.49 1537.0499999999997
# 10 156
# 11 134 9338.510000000015 1537.0499999999997
# 11 139
# 12 134 7571.455000000018 1537.0499999999997
# 12 138
# 13 134 5722.645000000007 1537.0499999999997
# 13 131
# 14 134 3746.009999999996 1537.0499999999997
# 14 133
# 15 134 1881.1300000000008 1537.0499999999997
# 15 127

# %%
out1.Final
# Out:
#    Season Crop Type Harvest Date (YYYY/MM/DD) Harvest Date (Step)  \
# 0       0     Maize                1985-09-11                 132
# 1       1     Maize                1986-09-12                 498
# 2       2     Maize                1987-09-10                 861
# 3       3     Maize                1988-09-05                1222
# 4       4     Maize                1989-09-21                1603
# 5       5     Maize                1990-09-13                1960
# 6       6     Maize                1991-09-06                2318
# 7       7     Maize                1992-09-29                2707
# 8       8     Maize                1993-10-06                3079
# 9       9     Maize                1994-09-04                3412
# 10     10     Maize                1995-10-04                3807
# 11     11     Maize                1996-09-17                4156
# 12     12     Maize                1997-09-16                4520
# 13     13     Maize                1998-09-09                4878
# 14     14     Maize                1999-09-11                5245
# 15     15     Maize                2000-09-05                5605
#
#     Yield (tonne/ha)  Seasonal irrigation (mm)
# 0          12.724061                   344.638
# 1          12.653570                   297.183
# 2          12.917810                   275.000
# 3          12.351369                   341.597
# 4          13.029625                   288.631
# 5          12.751070                   396.518
# 6          12.984444                   320.813
# 7          13.737808                    91.930
# 8          13.420057                   100.000
# 9          12.845073                   289.868
# 10         12.774868                   297.122
# 11         13.045981                    94.284
# 12         12.887744                   340.452
# 13         12.769300                   271.161
# 14         12.630683                   194.663
# 15         12.635779                   395.703

# %%
out=run_model(1985,2000,crop_params['Maize'],ma=True)
out.Final
# Out:
# 1 142 34699.960000000036 1670
# 1 144
# 2 142 32352.610000000015 1670
# 2 146
# 3 142 30034.45500000002 1670
# 3 139
# 4 142 27539.800000000032 1670
# 4 151
# 5 142 25206.735000000022 1670
# 5 144
# 6 142 22769.754999999997 1670
# 6 136
# 7 142 20287.84499999999 1670
# 7 157
# 8 142 18216.704999999976 1670
# 8 168
# 9 142 16077.204999999993 1670
# 9 134
# 10 142 13643.829999999982 1670
# 10 165
# 11 142 11384.694999999992 1670
# 11 157
# 12 142 9168.785000000022 1670
# 12 148
# 13 142 6908.170000000015 1670
# 13 138
# 14 142 4447.354999999996 1670
# 14 148
# 15 142 2032.0849999999996 1670
# 15 135
#    Season Crop Type Harvest Date (YYYY/MM/DD) Harvest Date (Step)  \
# 0       0     Maize                1985-09-20                 141
# 1       1     Maize                1986-09-22                 508
# 2       2     Maize                1987-09-24                 875
# 3       3     Maize                1988-09-17                1234
# 4       4     Maize                1989-09-29                1611
# 5       5     Maize                1990-09-22                1969
# 6       6     Maize                1991-09-14                2326
# 7       7     Maize                1992-10-05                2713
# 8       8     Maize                1993-10-16                3089
# 9       9     Maize                1994-09-12                3420
# 10     10     Maize                1995-10-13                3816
# 11     11     Maize                1996-10-05                4174
# 12     12     Maize                1997-09-26                4530
# 13     13     Maize                1998-09-16                4885
# 14     14     Maize                1999-09-26                5260
# 15     15     Maize                2000-09-13                5613
#
#     Yield (tonne/ha)  Seasonal irrigation (mm)
# 0          13.525931                491.871458
# 1          13.579622                370.742832
# 2          13.947034                370.110000
# 3          13.288273                441.597000
# 4          13.822551                388.631000
# 5          13.569871                471.641001
# 6          13.667289                395.813000
# 7          14.772051                216.940000
# 8          14.413870                199.700072
# 9          13.708655                413.491007
# 10         13.679972                347.122000
# 11         14.011053                166.913957
# 12         13.756258                465.461463
# 13         13.400631                345.011845
# 14         13.507079                269.663000
# 15         13.359647                520.160855

# %%
out.Final
# Out:
#    Season Crop Type Harvest Date (YYYY/MM/DD) Harvest Date (Step)  \
# 0       0     Maize                1985-09-20                 141
# 1       1     Maize                1986-09-22                 508
# 2       2     Maize                1987-09-24                 875
# 3       3     Maize                1988-09-17                1234
# 4       4     Maize                1989-09-29                1611
# 5       5     Maize                1990-09-22                1969
# 6       6     Maize                1991-09-14                2326
# 7       7     Maize                1992-10-05                2713
# 8       8     Maize                1993-10-16                3089
# 9       9     Maize                1994-09-12                3420
# 10     10     Maize                1995-10-13                3816
# 11     11     Maize                1996-10-05                4174
# 12     12     Maize                1997-09-26                4530
# 13     13     Maize                1998-09-16                4885
# 14     14     Maize                1999-09-26                5260
# 15     15     Maize                2000-09-13                5613
#
#     Yield (tonne/ha)  Seasonal irrigation (mm)
# 0          13.525931                491.871458
# 1          13.579622                370.742832
# 2          13.947034                370.110000
# 3          13.288273                441.597000
# 4          13.822551                388.631000
# 5          13.569871                471.641001
# 6          13.667289                395.813000
# 7          14.772051                216.940000
# 8          14.413870                199.700072
# 9          13.708655                413.491007
# 10         13.679972                347.122000
# 11         14.011053                166.913957
# 12         13.756258                465.461463
# 13         13.400631                345.011845
# 14         13.507079                269.663000
# 15         13.359647                520.160855

# %%
import matplotlib.pyplot as plt
plt.plot(out.Final['Yield (tonne/ha)'])
plt.plot(out1.Final['Yield (tonne/ha)'])

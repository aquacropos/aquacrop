# %%
from aquacrop.classes import    *
from aquacrop.core import       *
path = get_filepath('champion_climate.txt')
wdf = prepare_weather(path)
from aquacrop.crops.crop_params import crop_params

def run_model(year1,year2,crop_config,base=False):
    """
    funciton to run model and return results for given set of soil moisture targets
    """
    maize = CropClass('custom',PlantingDate='05/01',**crop_config) # define crop
    if base:
        maize = CropClass('Maize',PlantingDate='05/01',) # define crop

    loam = SoilClass('SiltClayLoam') # define soil
    init_wc = InitWCClass() # define initial soil water conditions

    irrmngt = IrrMngtClass(IrrMethod=1,SMT=[70]*4,) # define irrigation management
    # irrmngt = None

    # create and run model
    model = AquaCropModel(f'{year1}/05/01',f'{year2}/12/31',wdf,loam,maize,
                          IrrMngt=irrmngt,InitWC=init_wc,)
    model.initialize()
    model.step(till_termination=True)
    return model.Outputs

# %%
temp =crop_params['MaizeChampionGDD']
# temp['SwitchGDD']=1
out1=run_model(1985,2000,temp)

# %%
out1.Final
# Out:
#    Season         Crop Type Harvest Date (YYYY/MM/DD) Harvest Date (Step)  \
# 0       0  MaizeChampionGDD                1985-09-20                 141
# 1       1  MaizeChampionGDD                1986-09-22                 508
# 2       2  MaizeChampionGDD                1987-09-24                 875
# 3       3  MaizeChampionGDD                1988-09-17                1234
# 4       4  MaizeChampionGDD                1989-09-29                1611
# 5       5  MaizeChampionGDD                1990-09-22                1969
# 6       6  MaizeChampionGDD                1991-09-14                2326
# 7       7  MaizeChampionGDD                1992-10-05                2713
# 8       8  MaizeChampionGDD                1993-10-16                3089
# 9       9  MaizeChampionGDD                1994-09-12                3420
# 10     10  MaizeChampionGDD                1995-10-13                3816
# 11     11  MaizeChampionGDD                1996-10-05                4174
# 12     12  MaizeChampionGDD                1997-09-26                4530
# 13     13  MaizeChampionGDD                1998-09-16                4885
# 14     14  MaizeChampionGDD                1999-09-26                5260
# 15     15  MaizeChampionGDD                2000-09-13                5613
#
#     Yield (tonne/ha)  Seasonal irrigation (mm)
# 0          13.525931                491.871458
# 1          13.579622                370.742832
# 2          13.947034                370.110000
# 3          13.288273                441.597000
# 4          13.822551                388.631000
# 5          13.569871                471.641001
# 6          13.667289                395.813000
# 7          14.772051                216.940000
# 8          14.413870                199.700072
# 9          13.708655                413.491007
# 10         13.679972                347.122000
# 11         14.011053                166.913957
# 12         13.756258                465.461463
# 13         13.400631                345.011845
# 14         13.507079                269.663000
# 15         13.359647                520.160855

# %%
out=run_model(1985,2000,crop_params['Maize'],base=True)
out.Final
# Out:
#    Season Crop Type Harvest Date (YYYY/MM/DD) Harvest Date (Step)  \
# 0       0     Maize                1985-09-20                 141
# 1       1     Maize                1986-09-22                 508
# 2       2     Maize                1987-09-24                 875
# 3       3     Maize                1988-09-17                1234
# 4       4     Maize                1989-09-29                1611
# 5       5     Maize                1990-09-22                1969
# 6       6     Maize                1991-09-14                2326
# 7       7     Maize                1992-10-05                2713
# 8       8     Maize                1993-10-16                3089
# 9       9     Maize                1994-09-12                3420
# 10     10     Maize                1995-10-13                3816
# 11     11     Maize                1996-10-05                4174
# 12     12     Maize                1997-09-26                4530
# 13     13     Maize                1998-09-16                4885
# 14     14     Maize                1999-09-26                5260
# 15     15     Maize                2000-09-13                5613
#
#     Yield (tonne/ha)  Seasonal irrigation (mm)
# 0          13.525931                491.871458
# 1          13.579622                370.742832
# 2          13.947034                370.110000
# 3          13.288273                441.597000
# 4          13.822551                388.631000
# 5          13.569871                471.641001
# 6          13.667289                395.813000
# 7          14.772051                216.940000
# 8          14.413870                199.700072
# 9          13.708655                413.491007
# 10         13.679972                347.122000
# 11         14.011053                166.913957
# 12         13.756258                465.461463
# 13         13.400631                345.011845
# 14         13.507079                269.663000
# 15         13.359647                520.160855

# %%
out.Final
# Out:
#    Season Crop Type Harvest Date (YYYY/MM/DD) Harvest Date (Step)  \
# 0       0     Maize                1985-09-20                 141
# 1       1     Maize                1986-09-22                 508
# 2       2     Maize                1987-09-24                 875
# 3       3     Maize                1988-09-17                1234
# 4       4     Maize                1989-09-29                1611
# 5       5     Maize                1990-09-22                1969
# 6       6     Maize                1991-09-14                2326
# 7       7     Maize                1992-10-05                2713
# 8       8     Maize                1993-10-16                3089
# 9       9     Maize                1994-09-12                3420
# 10     10     Maize                1995-10-13                3816
# 11     11     Maize                1996-10-05                4174
# 12     12     Maize                1997-09-26                4530
# 13     13     Maize                1998-09-16                4885
# 14     14     Maize                1999-09-26                5260
# 15     15     Maize                2000-09-13                5613
#
#     Yield (tonne/ha)  Seasonal irrigation (mm)
# 0          13.525931                491.871458
# 1          13.579622                370.742832
# 2          13.947034                370.110000
# 3          13.288273                441.597000
# 4          13.822551                388.631000
# 5          13.569871                471.641001
# 6          13.667289                395.813000
# 7          14.772051                216.940000
# 8          14.413870                199.700072
# 9          13.708655                413.491007
# 10         13.679972                347.122000
# 11         14.011053                166.913957
# 12         13.756258                465.461463
# 13         13.400631                345.011845
# 14         13.507079                269.663000
# 15         13.359647                520.160855

# %%
import matplotlib.pyplot as plt
plt.plot(out.Final['Yield (tonne/ha)'])
plt.plot(out1.Final['Yield (tonne/ha)'])
